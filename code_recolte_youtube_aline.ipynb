# %%
pip install google-api-python-client pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build
import pandas as pd

# 1️⃣ Configurer l'API
api_key = "AIzaSyBv-is97z465BHqY9WbDh9G47TGy8-1pkM"
youtube = build('youtube', 'v3', developerKey=api_key)

# 2️⃣ Appeler l'API pour récupérer les vidéos tendances
request = youtube.videos().list(
    part="snippet,statistics,contentDetails",
    chart="mostPopular",
    regionCode="FR",  # Change selon le pays
    maxResults=10      # Nombre de vidéos à récupérer
)
response = request.execute()

# 3️⃣ Extraire les données pertinentes
videos = []
for item in response['items']:
    video_data = {
        "video_id": item['id'],
        "title": item['snippet']['title'],
        "channel_title": item['snippet']['channelTitle'],
        "publish_date": item['snippet']['publishedAt'],
        "views": item['statistics'].get('viewCount', 0),
        "likes": item['statistics'].get('likeCount', 0),
        "comments": item['statistics'].get('commentCount', 0),
        "duration": item['contentDetails']['duration'],
        "tags": item['snippet'].get('tags', [])
    }
    videos.append(video_data)

# 4️⃣ Convertir en DataFrame pour analyse
df_videos = pd.DataFrame(videos)
print(df_videos)
# Out:
#       video_id                                              title  \
# 0  a3v4Va8r6e8                 Niaks - JACK HONEY (Clip officiel)
# 1  iyMI9ES-7Nc  The Sims 4: Royalty & Legacy | Official Reveal...
# 2  _3eGWztxBM8                            LA CHASSE AU POKÉDEX !!
# 3  hT8nvc6fxBs  GIMS (ft. @Theodorabosslady ) - SPA (Official ...
# 4  -1UJJPAWudQ              Euphoria Season 3 | Trailer | HBO Max
# 5  FFayd5WjW8s  0€ À 100T UNIQUEMENT AVEC DES BRAINROTS BÉBÉS !!
# 6  jJLD0YlzeFE                                          STOCKHOLM
# 7  mTW26ZrIuyA  EUPHORIA Saison 3 Bande Annonce VF (2026) Sydn...
# 8  S-GOCLmlsdI  J'ai Recruté Des GARDES DU CORPS Pour PROTEGER...
# 9  R6e4tBWxIxE                 ENHYPEN (엔하이픈) 'Knife' Official MV
#
#    channel_title          publish_date    views   likes comments  duration  \
# 0          Niaks  2026-01-15T17:00:07Z   114990    6633      405   PT2M22S
# 1       The Sims  2026-01-15T15:58:06Z   396821   23656     2720   PT2M40S
# ...

# %%
df_videos
# Out:
#       video_id                                              title  \
# 0  a3v4Va8r6e8                 Niaks - JACK HONEY (Clip officiel)
# 1  iyMI9ES-7Nc  The Sims 4: Royalty & Legacy | Official Reveal...
# 2  _3eGWztxBM8                            LA CHASSE AU POKÉDEX !!
# 3  hT8nvc6fxBs  GIMS (ft. @Theodorabosslady ) - SPA (Official ...
# 4  -1UJJPAWudQ              Euphoria Season 3 | Trailer | HBO Max
# 5  FFayd5WjW8s  0€ À 100T UNIQUEMENT AVEC DES BRAINROTS BÉBÉS !!
# 6  jJLD0YlzeFE                                          STOCKHOLM
# 7  mTW26ZrIuyA  EUPHORIA Saison 3 Bande Annonce VF (2026) Sydn...
# 8  S-GOCLmlsdI  J'ai Recruté Des GARDES DU CORPS Pour PROTEGER...
# 9  R6e4tBWxIxE                 ENHYPEN (엔하이픈) 'Knife' Official MV
#
#    channel_title          publish_date    views   likes comments  duration  \
# 0          Niaks  2026-01-15T17:00:07Z   114990    6633      405   PT2M22S
# 1       The Sims  2026-01-15T15:58:06Z   396821   23656     2720   PT2M40S
# ...

# %%
df_videos.shape
# Out:
# (10, 9)
