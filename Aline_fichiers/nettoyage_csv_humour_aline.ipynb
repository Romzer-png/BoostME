# %%
import requests
import pandas as pd
import glob

# %%
# récupérer tous les fichiers du dossier videos et dédupliquer les lignes
files = glob.glob("market_humour_fr.csv")

df = []
for f in files:
    csv = pd.read_csv(f)
    df.append(csv)
df = pd.concat(df,ignore_index=True)
df.drop_duplicates(subset=['video_id'], keep="first", inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   video_id      989 non-null    object
#  1   title         989 non-null    object
#  2   description   459 non-null    object
#  3   channel_id    989 non-null    object
#  4   category_id   989 non-null    int64
#  5   language      963 non-null    object
#  6   channel       989 non-null    object
#  7   published_at  989 non-null    object
#  8   duration      988 non-null    object
#  9   views         989 non-null    int64
#  10  likes         989 non-null    int64
#  11  comments      989 non-null    int64
# dtypes: int64(4), object(8)
# memory usage: 92.8+ KB

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  eVrbPNIHfHY      LES JEUNES EN SALLE DE SPORT💪🤣#humour #shorts
# 1  kMPxRclSRrE  Je ne suis qu’un homme!!! #humour #lol #love #...
# 2  E9CnEeOdESk                      Sacha Ferra – C'est son style
# 3  9qnIkeqYWtE  Por favor comparte con tus amigos #pov #herram...
# 4  hTKWX0cQtiE  Le dialogue le plus WTF jamais entendu ? #humo...
#
#                                          description  \
# 0                                                NaN
# 1                                                NaN
# 2  Sacha Ferra – C'est son style\n\n𝙀𝙉𝙑𝙄𝙀 𝘿'𝙀𝙉𝘾𝙊𝙍...
# 3                                                NaN
# 4  C'est un papier qui tombe à l'eau. Et il crie,...
#
#                  channel_id  category_id language          channel  \
# 0  UCpsvoU1qL4WLR6jvh1CWjhw           22       fr      Le déraciné
# 1  UCcIk1sZMBTu91ZxUHLr-BOg           23       fr      Kévin Lévy
# 2  UCPHJfLg1VeNBsfzzTszpmmQ           23       fr  Montreux Comedy
# 3  UCUnw7mc6iHy8vZe8mvMKlUA           22       en       Mai Nguyên
# 4  UCIQs0qjGOmjV2jTkazCvXyQ           22       fr         comedyUp
#
#            published_at  duration    views  likes  comments
# 0  2025-06-16T16:01:04Z     PT11S  2640830  49359       450
# 1  2025-12-14T16:31:40Z     PT26S   919082   8487       144
# 2  2025-10-08T16:00:32Z  PT10M29S   143065   4670        81
# 3  2026-01-22T10:03:17Z     PT58S     1522     47        15
# 4  2025-12-20T22:08:50Z     PT17S   523750   2404         3

# %%
# langues: supprimer les lignes avec valeurs
df.dropna(subset="language",axis=0,inplace=True)

# langues: regrouper fr_fr, be_fr sous 'fr', pareil pour 'en'
df.loc[df['language'].str.contains('^fr'),'language'] = "fr"
df.loc[df['language'].str.contains('^en'),'language'] = "en"

# %%
#supprimer autres langues
df['language'].value_counts()
# Out:
# language
# fr       586
# en       209
# hi        86
# es        13
# de        11
# ru         8
# id         6
# vi         5
# pt-PT      5
# zxx        5
# tr         5
# und        2
# ko         2
# nl-NL      2
# bn         2
# pt-BR      2
# de-DE      2
# chr        1
# ja         1
# wo         1
# ar         1
# nl         1
# es-MX      1
# or         1
# pa         1
# ta         1
# bn-IN      1
# pl         1
# gu         1
# Name: count, dtype: int64

# %%
# calculer le taux d'engagement pour voir en un coup d'oeil les vidéos ayant reçu le plus d'intéractions
df["Engagement total"] = df["likes"] + df["comments"]
df["Taux d'engagement (%)"] = (df["Engagement total"] / df["views"].replace(0, 1)) * 100

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  eVrbPNIHfHY      LES JEUNES EN SALLE DE SPORT💪🤣#humour #shorts
# 1  kMPxRclSRrE  Je ne suis qu’un homme!!! #humour #lol #love #...
# 2  E9CnEeOdESk                      Sacha Ferra – C'est son style
# 3  9qnIkeqYWtE  Por favor comparte con tus amigos #pov #herram...
# 4  hTKWX0cQtiE  Le dialogue le plus WTF jamais entendu ? #humo...
#
#                                          description  \
# 0                                                NaN
# 1                                                NaN
# 2  Sacha Ferra – C'est son style\n\n𝙀𝙉𝙑𝙄𝙀 𝘿'𝙀𝙉𝘾𝙊𝙍...
# 3                                                NaN
# 4  C'est un papier qui tombe à l'eau. Et il crie,...
#
#                  channel_id  category_id language          channel  \
# 0  UCpsvoU1qL4WLR6jvh1CWjhw           22       fr      Le déraciné
# 1  UCcIk1sZMBTu91ZxUHLr-BOg           23       fr      Kévin Lévy
# 2  UCPHJfLg1VeNBsfzzTszpmmQ           23       fr  Montreux Comedy
# 3  UCUnw7mc6iHy8vZe8mvMKlUA           22       en       Mai Nguyên
# 4  UCIQs0qjGOmjV2jTkazCvXyQ           22       fr         comedyUp
#
#            published_at  duration    views  likes  comments  Engagement total  \
# 0  2025-06-16T16:01:04Z     PT11S  2640830  49359       450             49809
# 1  2025-12-14T16:31:40Z     PT26S   919082   8487       144              8631
# 2  2025-10-08T16:00:32Z  PT10M29S   143065   4670        81              4751
# 3  2026-01-22T10:03:17Z     PT58S     1522     47        15                62
# 4  2025-12-20T22:08:50Z     PT17S   523750   2404         3              2407
#
#    Taux d'engagement (%)
# 0               1.886112
# 1               0.939089
# 2               3.320868
# 3               4.073587
# 4               0.459570

# %%
# transofrmer les durées (ici min/sec) en secondes (plus simple pour l'analyse
import re

# 1. Conversion en timedelta (errors='coerce' transforme les formats invalides en NaT)
df['duration_td'] = pd.to_timedelta(df['duration'], errors='coerce')

# 2. Conversion en secondes
# .astype('Int64') permet de garder les NaN si nécessaire sans faire planter le code
df['Durée (s)'] = df['duration_td'].dt.total_seconds().astype('Int64')

# OPTIONNEL : Si vous voulez remplacer les vides par 0 et avoir des entiers classiques
# df['Durée (s)'] = df['duration_td'].dt.total_seconds().fillna(0).astype(int)

print(df[['duration', 'Durée (s)']])
# Out:
#      duration  Durée (s)
# 0       PT11S         11
# 1       PT26S         26
# 2    PT10M29S        629
# 3       PT58S         58
# 4       PT17S         17
# ..        ...        ...
# 983     PT49S         49
# 984   PT1M30S         90
# 985     PT21S         21
# 986     PT31S         31
# 988   PT1M47S        107
#
# [963 rows x 2 columns]

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  eVrbPNIHfHY      LES JEUNES EN SALLE DE SPORT💪🤣#humour #shorts
# 1  kMPxRclSRrE  Je ne suis qu’un homme!!! #humour #lol #love #...
# 2  E9CnEeOdESk                      Sacha Ferra – C'est son style
# 3  9qnIkeqYWtE  Por favor comparte con tus amigos #pov #herram...
# 4  hTKWX0cQtiE  Le dialogue le plus WTF jamais entendu ? #humo...
#
#                                          description  \
# 0                                                NaN
# 1                                                NaN
# 2  Sacha Ferra – C'est son style\n\n𝙀𝙉𝙑𝙄𝙀 𝘿'𝙀𝙉𝘾𝙊𝙍...
# 3                                                NaN
# 4  C'est un papier qui tombe à l'eau. Et il crie,...
#
#                  channel_id  category_id language          channel  \
# 0  UCpsvoU1qL4WLR6jvh1CWjhw           22       fr      Le déraciné
# 1  UCcIk1sZMBTu91ZxUHLr-BOg           23       fr      Kévin Lévy
# 2  UCPHJfLg1VeNBsfzzTszpmmQ           23       fr  Montreux Comedy
# 3  UCUnw7mc6iHy8vZe8mvMKlUA           22       en       Mai Nguyên
# 4  UCIQs0qjGOmjV2jTkazCvXyQ           22       fr         comedyUp
#
#            published_at  duration    views  likes  comments  Engagement total  \
# 0  2025-06-16T16:01:04Z     PT11S  2640830  49359       450             49809
# 1  2025-12-14T16:31:40Z     PT26S   919082   8487       144              8631
# 2  2025-10-08T16:00:32Z  PT10M29S   143065   4670        81              4751
# 3  2026-01-22T10:03:17Z     PT58S     1522     47        15                62
# 4  2025-12-20T22:08:50Z     PT17S   523750   2404         3              2407
#
#    Taux d'engagement (%)     duration_td  Durée (s)
# 0               1.886112 0 days 00:00:11         11
# 1               0.939089 0 days 00:00:26         26
# 2               3.320868 0 days 00:10:29        629
# 3               4.073587 0 days 00:00:58         58
# 4               0.459570 0 days 00:00:17         17

# %%
df.shape
# Out:
# (963, 16)

# %%
# colonnes avec valeurs nulls
df.isna().sum()
# Out:
# video_id                   0
# title                      0
# description              525
# channel_id                 0
# category_id                0
# language                   0
# channel                    0
# published_at               0
# duration                   1
# views                      0
# likes                      0
# comments                   0
# Engagement total           0
# Taux d'engagement (%)      0
# duration_td                1
# Durée (s)                  1
# dtype: int64

# %%
df.to_csv("market_humour_clean.csv", index=False)
