# %%
# 1FPUEC1YzdyRyrLV9Ufmr39CgI5aclN_T

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in c:\users\administrateur\anaconda3\lib\site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\administrateur\anaconda3\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in c:\users\administrateur\anaconda3\lib\site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\administrateur\anaconda3\lib\site-packages (from gdown) (2.32.2)
# Requirement already satisfied: tqdm in c:\users\administrateur\anaconda3\lib\site-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\administrateur\anaconda3\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrateur\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrateur\anaconda3\lib\site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrateur\anaconda3\lib\site-packages (from requests[socks]->gdown) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrateur\anaconda3\lib\site-packages (from requests[socks]->gdown) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\administrateur\anaconda3\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\administrateur\anaconda3\lib\site-packages (from tqdm->gdown) (0.4.6)

# %%
import gdown

file_id = "1FPUEC1YzdyRyrLV9Ufmr39CgI5aclN_T"  # Remplace par ton ID
url = f"https://drive.google.com/uc?id={file_id}"
output = "trend_videos_youtube_aline.csv"  # Nom local pour le CSV
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FPUEC1YzdyRyrLV9Ufmr39CgI5aclN_T
# To: C:\Users\Administrateur\GoogleDrive\Mon Drive\WILD CODE SCHOOL\Session 2025\PROJETS\PROJET_3\BoostME\trend_videos_youtube_aline.csv
# 100%|██████████| 429k/429k [00:00<00:00, 7.74MB/s]
# 'trend_videos_youtube_aline.csv'

# %%
import pandas as pd

df = pd.read_csv("trend_videos_youtube_aline.csv")
df.head()
# Out:
#       Video ID                                              Titre  \
# 0  UcLj3wLcQF4  RnBoi & Nono La Grinta - AVEC MOI (Clip Officiel)
# 1  Zv_Te5PthuM  LES K D'OR Bande Annonce (2026) Jeremy Ferrari...
# 2  5sIXk8in27s  DÉSOLÉ ON PEUT PAS VOUS SERVIR VOUS ÊTES TROP ...
# 3  BWfKkqo1Mk8                                  EXO 엑소 'Crown' MV
# 4  C2VJFYZ6cak  Bande annonce Les K d’or - Un film de Jérémy F...
#
#                                          Description Date de publication  \
# 0  “AVEC MOI” Feat. Nono La Grinta - nouveau sing...    16/01/2026 17:00
# 1  ✩ Les Films à VOIR ?  Ils sont ICI ► https://w...    18/01/2026 17:34
# 2  On prépare un bon shawarma pour nos clients mê...    18/01/2026 13:00
# 3  EXO's 8th album "REVERXE" is out!\nListen and ...    19/01/2026 09:00
# 4  LE 11 MARS AU CINÉMA \n\nRéservation pour les ...    18/01/2026 16:49
#
#   Durée (min:sec)    Vues   Likes  Commentaires               Genre  \
# 0            2:57  607864   32780          1022             Musique
# 1            1:50   15810     454            57  Cinéma & Animation
# 2           16:21  299290   25261           168          Jeux vidéo
# 3            3:32  883600  218627         31861             Musique
# 4            1:30   13349     702            31  Cinéma & Animation
#
#                     Nom de la chaîne                   Nom du youtubeur  \
# 0                              RnBoi                              RnBoi
# 1                          FilmsActu                          FilmsActu
# 2  Wankil Studio - Laink et Terracid  Wankil Studio - Laink et Terracid
# 3                             SMTOWN                             SMTOWN
# 4                     JEREMY FERRARI                     JEREMY FERRARI
#
#                                    Lien de la chaîne Pays
# 0  https://www.youtube.com/channel/UCEvTUVFFOBTRv...   FR
# 1  https://www.youtube.com/channel/UC_i8X3p8oZNai...   FR
# 2  https://www.youtube.com/channel/UCYGjxo5ifuhnm...   FR
# 3  https://www.youtube.com/channel/UCEf_Bc-KVd7on...   FR
# 4  https://www.youtube.com/channel/UCOeQ-23M6TlRZ...   FR

# %%
# Vérifier les valeurs manquantes
print(df.isnull().sum())

# Vérifier les doublons sur l'ID vidéo
print("Doublons Video ID :", df.duplicated(subset="Video ID").sum())

# Supprimer les doublons si nécessaire
df = df.drop_duplicates(subset="Video ID")
# Out:
# Video ID               0
# Titre                  0
# Description            4
# Date de publication    0
# Durée (min:sec)        0
# Vues                   0
# Likes                  0
# Commentaires           0
# Genre                  0
# Nom de la chaîne       0
# Nom du youtubeur       0
# Lien de la chaîne      0
# Pays                   0
# dtype: int64
# Doublons Video ID : 10

# %%
# Vérifier les doublons sur l'ID vidéo
print("Doublons Video ID :", df.duplicated(subset="Video ID").sum())
# Out:
# Doublons Video ID : 0

# %%
# normaliser les formats
# transofrmer les durées (ici min/sec) en secondes (plus simple pour l'analyse
import re

def duration_to_seconds(duration_str):
    # Convertit "minutes:seconds" en secondes
    match = re.match(r"(\d+):(\d+)", duration_str)
    if match:
        minutes, seconds = match.groups()
        return int(minutes) * 60 + int(seconds)
    return 0

df["Durée (s)"] = df["Durée (min:sec)"].apply(duration_to_seconds)

# %%
# ajout de colonnes de dates et heures de publication pour analyser les meilleurs moments pour publier
df["Date de publication"] = pd.to_datetime(df["Date de publication"], format="%d/%m/%Y %H:%M")
df["Année"] = df["Date de publication"].dt.year
df["Mois"] = df["Date de publication"].dt.month
df["Jour"] = df["Date de publication"].dt.day
df["Heure"] = df["Date de publication"].dt.hour
df["Jour de la semaine"] = df["Date de publication"].dt.day_name()

# %%
# calcuker le taux d'engagement pour voir en un coup d'oeil les vidéos ayant reçu le plus d'intéractions
df["Engagement total"] = df["Likes"] + df["Commentaires"]
df["Taux d'engagement (%)"] = (df["Engagement total"] / df["Vues"].replace(0, 1)) * 100

# %%
# remplacer les valeurs manquantes dans genre par "Inconnu"

print(df["Genre"].value_counts())

# Remplacer les valeurs manquantes ou "Inconnu"
df["Genre"] = df["Genre"].fillna("Inconnu")
# Out:
# Genre
# Jeux vidéo            291
# Musique                47
# Divertissement         35
# Cinéma & Animation      5
# Lifestyle & Blogs       5
# Humour                  3
# Automobile              2
# Sport & Fitness         2
# Name: count, dtype: int64

# %%
# ajout d'une colonne[Descritpion_clean] pour pousser les analyse par mots clés (NLP, hashtags, mots clés)
# Nettoyer les descriptions
df["Description_clean"] = df["Description"].str.replace(r'\n', ' ', regex=True)
df["Description_clean"] = df["Description_clean"].str.strip()

# %%
df.to_csv("trend_youtube_aline_clean.csv", index=False)

# %%
df
# Out:
#         Video ID                                              Titre  \
# 0    UcLj3wLcQF4  RnBoi & Nono La Grinta - AVEC MOI (Clip Officiel)
# 1    Zv_Te5PthuM  LES K D'OR Bande Annonce (2026) Jeremy Ferrari...
# 2    5sIXk8in27s  DÉSOLÉ ON PEUT PAS VOUS SERVIR VOUS ÊTES TROP ...
# 3    BWfKkqo1Mk8                                  EXO 엑소 'Crown' MV
# 4    C2VJFYZ6cak  Bande annonce Les K d’or - Un film de Jérémy F...
# ..           ...                                                ...
# 395  1mbRza4uuhc          Ligue 1 2025-26: AS Monaco vs. FC Lorient
# 396  nltcjR96_5w  We Built the Ultimate Lava Cave Fortress in AR...
# 397  coINcI8CqUI                     This YouTuber is Lying to You.
# 398  aLi34ByfOYE               MMG's BEST Madden Pulls Of ALL TIME!
# 399  cwd6H4mgUIQ  Patch 16.3 Rundown | TFT Lore & Legends | Team...
#
#                                            Description Date de publication  \
# 0    “AVEC MOI” Feat. Nono La Grinta - nouveau sing... 2026-01-16 17:00:00
# 1    ✩ Les Films à VOIR ?  Ils sont ICI ► https://w... 2026-01-18 17:34:00
# 2    On prépare un bon shawarma pour nos clients mê... 2026-01-18 13:00:00
# 3    EXO's 8th album "REVERXE" is out!\nListen and ... 2026-01-19 09:00:00
# 4    LE 11 MARS AU CINÉMA \n\nRéservation pour les ... 2026-01-18 16:49:00
# ..                                                 ...                 ...
# 395                                From Jan. 16, 2026. 2026-01-07 01:11:00
# 396  ⚔️ Play ASSASSIN’S CREED in Raid ⚔️ Get Ezio +... 2026-01-18 17:01:00
# 397  SUBSCRIBE AND GET US TO 4M BEFORE THE EVIL YOU... 2026-01-19 01:36:00
# 398  If you want a trip down memory lane, here it i... 2026-01-19 05:57:00
# 399  Originally Aired: Jan 18, 2026\n\nTwitch: http... 2026-01-18 18:00:00
#
#     Durée (min:sec)    Vues   Likes  Commentaires               Genre  \
# 0              2:57  607864   32780          1022             Musique
# 1              1:50   15810     454            57  Cinéma & Animation
# 2             16:21  299290   25261           168          Jeux vidéo
# 3              3:32  883600  218627         31861             Musique
# 4              1:30   13349     702            31  Cinéma & Animation
# ..              ...     ...     ...           ...                 ...
# 395            0:00       0       0             0      Divertissement
# 396           65:15   64759    2821           244          Jeux vidéo
# 397            9:31  110007    9912          3273          Jeux vidéo
# 398           60:00   26955    1328           121          Jeux vidéo
# 399           52:42  118658    3185           630          Jeux vidéo
#
#                       Nom de la chaîne  ... Pays Durée (s) Année  Mois  Jour  \
# 0                                RnBoi  ...   FR       177  2026     1    16
# 1                            FilmsActu  ...   FR       110  2026     1    18
# 2    Wankil Studio - Laink et Terracid  ...   FR       981  2026     1    18
# 3                               SMTOWN  ...   FR       212  2026     1    19
# 4                       JEREMY FERRARI  ...   FR        90  2026     1    18
# ..                                 ...  ...  ...       ...   ...   ...   ...
# 395                        BeIN Sports  ...   US         0  2026     1     7
# 396                              Xavii  ...   US      3915  2026     1    18
# 397                              Uzoth  ...   US       571  2026     1    19
# 398                              Meags  ...   US      3600  2026     1    19
# 399                      Mortdog - TFT  ...   US      3162  2026     1    18
#
#      Heure  Jour de la semaine  Engagement total Taux d'engagement (%)  \
# 0       17              Friday             33802              5.560783
# 1       17              Sunday               511              3.232132
# 2       13              Sunday             25429              8.496442
# 3        9              Monday            250488             28.348574
# 4       16              Sunday               733              5.491048
# ..     ...                 ...               ...                   ...
# 395      1           Wednesday                 0              0.000000
# 396     17              Sunday              3065              4.732933
# 397      1              Monday             13185             11.985601
# 398      5              Monday              1449              5.375626
# 399     18              Sunday              3815              3.215122
#
#                                      Description_clean
# 0    “AVEC MOI” Feat. Nono La Grinta - nouveau sing...
# 1    ✩ Les Films à VOIR ?  Ils sont ICI ► https://w...
# 2    On prépare un bon shawarma pour nos clients mê...
# 3    EXO's 8th album "REVERXE" is out! Listen and d...
# 4    LE 11 MARS AU CINÉMA   Réservation pour les av...
# ..                                                 ...
# 395                                From Jan. 16, 2026.
# 396  ⚔️ Play ASSASSIN’S CREED in Raid ⚔️ Get Ezio +...
# 397  SUBSCRIBE AND GET US TO 4M BEFORE THE EVIL YOU...
# 398  If you want a trip down memory lane, here it i...
# 399  Originally Aired: Jan 18, 2026  Twitch: https:...
#
# [390 rows x 22 columns]
